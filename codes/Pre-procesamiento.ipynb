# %%
import os
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
os.chdir("/content/drive/MyDrive/DPB2_Claudia Camacho")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Español

# %%
distorsiones_cognitivas_traducidas = {
    "negative feeling or emotion": "Sentimiento o emoción negativa",
    "No Distortion": "Sin distorsión",
    'none' : 'Sin distorsión',
    "Mind Reading": "Lectura de mente",
    "Overgeneralization": "Sobregeneralización",
    "Magnification": "Magnificación",
    "Personalization": "Personalización",
    "Fortune-telling": "Error del adivino",
    'fortune telling': "Error del adivino",
    "Emotional Reasoning": "Razonamiento emocional",
    "Mental filter": "Filtro mental",
    "Should statements": "Debería (frase)",
    "All-or-nothing thinking": "Todo o nada",
    'no distortion': 'Sin distorsión',
    'mind reading': 'Lectura de mente',
    'overgeneralizing': 'Sobregeneralización',
    'ovegeneralization' : 'Sobregeneralización',
    'magnification': 'Magnificación',
    'Labeling': 'Etiquetamiento erróneo',
    'labeling': 'Etiquetamiento erróneo',
    'personalization': 'Personalización',
    'personalizing' : 'Personalización',
    'fortune-telling': 'Error del adivino',
    'emotional reasoning': 'Razonamiento emocional',
    'mental filter': 'Filtro mental',
    'should statements': 'Debería (frase)',
    'all-or-nothing thinking': 'Todo o nada',
    'disqualifying the positive':'Descalificación de lo positivo',
    'catastrophizing':'Catastroficación',
    'blaming':'Culpar a otros',
    "comparing and despairing": "Comparaciones desalentadoras"}

# %% [markdown]
# ## Inglés

# %%
distorsiones_cognitivas_traducidas = {
    "negative feeling or emotion": "Sentimiento o emoción negativa",
    "No Distortion": "No distorsion",
    'none' : 'No distorsion',
    "Mind Reading": "Mind reading",
    "Overgeneralization": "Overgeneralization",
    "Magnification": "Magnification",
    "Personalization": "Personalization",
    "Fortune-telling": "Fortune telling",
    'fortune telling': "Fortune telling",
    "Emotional Reasoning": "Emotional reasoning",
    "Mental filter": "Mental filter",
    "Should statements": "Should statements",
    "All-or-nothing thinking": "All or nothing",
    'no distortion': 'No distorsion',
    'mind reading': 'Mind reading',
    'overgeneralizing': 'Overgeneralization',
    'ovegeneralization' : 'Overgeneralization',
    'magnification': 'Magnification',
    'Labeling': 'Labeling',
    'labeling': 'Labeling',
    'personalization': 'Personalization',
    'personalizing' : 'Personalization',
    'fortune-telling': 'Fortune telling',
    'emotional reasoning': 'Emotional reasoning',
    'mental filter': 'Mental filter',
    'should statements': 'Should statements',
    'all-or-nothing thinking': 'All or nothing',
    'disqualifying the positive':'Disqualifying the positive',
    'catastrophizing':'Catastrophizing',
    'blaming':'Blaming',
    "comparing and despairing": "Comparing and despairing"}

# %% [markdown]
# ## D1

# %%
# !mkdir -p ~/.kaggle
# !cp ./kaggle_file/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
import pandas as pd
import kaggle
import numpy as np
kaggle.api.dataset_download_files('sagarikashreevastava/cognitive-distortion-detetction-dataset', path='data', unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sagarikashreevastava/cognitive-distortion-detetction-dataset

# %%
d1 = pd.read_csv('data/Annotated_data.csv')
d1['Texto'] = d1['Patient Question'] + [x if isinstance(x, str) else ' ' for x in d1['Distorted part']]
d1['Dominant Distortion'] = d1['Dominant Distortion'].replace(distorsiones_cognitivas_traducidas)
d1['Secondary Distortion (Optional)'] = d1['Secondary Distortion (Optional)'].replace(distorsiones_cognitivas_traducidas)
d1['Distorsión'] = d1.apply(lambda x: ','.join([str(y) for y in [x['Dominant Distortion'], x['Secondary Distortion (Optional)']] if pd.notna(y)]), axis=1)
d1['Dataset'] = 'D1'

# %%
d1.head()
# Out:
#    Id_Number                                   Patient Question  \
# 0       4500  Hello, I have a beautiful,smart,outgoing and a...
# 1       4501  Since I was about 16 years old I’ve had these ...
# 2       4502   So I’ve been dating on and off this guy for a...
# 3       4503  My parents got divorced in 2004. My mother has...
# 4       4504  I don’t really know how to explain the situati...
#
#                                       Distorted part     Dominant Distortion  \
# 0  The voice are always fimilar (someone she know...         Personalización
# 1  I feel trapped inside my disgusting self and l...  Etiquetamiento erróneo
# 2                                                NaN          Sin distorsión
# 3                                                NaN          Sin distorsión
# 4  I refused to go because I didn’t know if it wa...       Error del adivino
#
#   Secondary Distortion (Optional)  \
# 0                             NaN
# 1          Razonamiento emocional
# 2                             NaN
# 3                             NaN
# 4          Razonamiento emocional
#
#                                                Texto  \
# 0  Hello, I have a beautiful,smart,outgoing and a...
# 1  Since I was about 16 years old I’ve had these ...
# 2   So I’ve been dating on and off this guy for a...
# 3  My parents got divorced in 2004. My mother has...
# 4  I don’t really know how to explain the situati...
#
#                                       Distorsión Dataset
# 0                                Personalización      D1
# 1  Etiquetamiento erróneo,Razonamiento emocional      D1
# 2                                 Sin distorsión      D1
# 3                                 Sin distorsión      D1
# 4       Error del adivino,Razonamiento emocional      D1

# %% [markdown]
# ## D2

# %%
d2 = pd.read_excel('data/dataseet_chinatraducida.xlsx')
d2['Texto'] = d2['Situation or Thinking']
d2['Distorsión'] = [",".join(map(lambda x:distorsiones_cognitivas_traducidas[x.lower()], i.split(','))) for i in d2['Cognitive Distortion']]
d2['Dataset'] = 'D2'

# %%
d2.head()
# Out:
#                                Situation or Thinking Cognitive Distortion  \
# 0  wanted to see you, but I promised someone else...     labeling,blaming
# 1  I suddenly feel like I don't have a single fri...      fortune telling
# 2  I am so tired... really tired... I can never p...    ovegeneralization
# 3  I can't stand it anymore. I can't stand having...             labeling
# 4        I'm always avoiding things, I'm so useless.             labeling
#
#                                                Texto  \
# 0  wanted to see you, but I promised someone else...
# 1  I suddenly feel like I don't have a single fri...
# 2  I am so tired... really tired... I can never p...
# 3  I can't stand it anymore. I can't stand having...
# 4        I'm always avoiding things, I'm so useless.
#
#                               Distorsión Dataset
# 0  Etiquetamiento erróneo,Culpar a otros      D2
# 1                      Error del adivino      D2
# 2                    Sobregeneralización      D2
# 3                 Etiquetamiento erróneo      D2
# 4                 Etiquetamiento erróneo      D2

# %% [markdown]
# ## D3

# %%
d3 = pd.read_csv('data/reframing_dataset.csv')
d3['Texto'] = d3['situation'] + ' ' + d3['thought']
d3['Distorsión'] =  [",".join(map(lambda x:distorsiones_cognitivas_traducidas[x.lower()], i.split(','))) for i in d3['thinking_traps_addressed']]
d3['Dataset'] = 'D3'

# %%
d3.head()
# Out:
#                                            situation  \
# 0                A Roomate of mine stole my comptuer
# 1                A Roomate of mine stole my comptuer
# 2  A few days ago, I got angry at my husband's gr...
# 3  A few days ago, I got angry at my husband's gr...
# 4  A friend who is a recent widower has started d...
#
#                                              thought  \
# 0  Someone I trusted stole something valuable of ...
# 1  Someone I trusted stole something valuable of ...
# 2                            She doesn't respect me.
# 3                            She doesn't respect me.
# 4  My friend is ignoring his recently-deceased wife.
#
#                                              reframe  \
# 0  My roommate stole something of mine, and I wil...
# 1  While I would like there to be consequences fo...
# 2               She is older and may have been tired
# 3  I felt disrespected by her actions, but that d...
# 4  Maybe my friend is in a healthy spot to date n...
#
#      thinking_traps_addressed  \
# 0         emotional reasoning
# 1         emotional reasoning
# 2            overgeneralizing
# 3            overgeneralizing
# 4  disqualifying the positive
#
#                                                Texto  \
# 0  A Roomate of mine stole my comptuer Someone I ...
# 1  A Roomate of mine stole my comptuer Someone I ...
# 2  A few days ago, I got angry at my husband's gr...
# 3  A few days ago, I got angry at my husband's gr...
# 4  A friend who is a recent widower has started d...
#
#                        Distorsión Dataset
# 0          Razonamiento emocional      D3
# 1          Razonamiento emocional      D3
# 2             Sobregeneralización      D3
# 3             Sobregeneralización      D3
# 4  Descalificación de lo positivo      D3

# %% [markdown]
# ## Prevención de desbalance

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2530 entries, 0 to 2529
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Id_Number                        2530 non-null   int64
#  1   Patient Question                 2530 non-null   object
#  2   Distorted part                   1597 non-null   object
#  3   Dominant Distortion              2530 non-null   object
#  4   Secondary Distortion (Optional)  416 non-null    object
#  5   Texto                            2530 non-null   object
#  6   Distorsión                       2530 non-null   object
#  7   Dataset                          2530 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 158.2+ KB

# %%
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 728 entries, 0 to 727
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Situation or Thinking  728 non-null    object
#  1   Cognitive Distortion   728 non-null    object
#  2   Texto                  728 non-null    object
#  3   Distorsión             728 non-null    object
#  4   Dataset                728 non-null    object
# dtypes: object(5)
# memory usage: 28.6+ KB

# %%
d3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   situation                 600 non-null    object
#  1   thought                   600 non-null    object
#  2   reframe                   600 non-null    object
#  3   thinking_traps_addressed  600 non-null    object
#  4   Texto                     600 non-null    object
#  5   Distorsión                600 non-null    object
#  6   Dataset                   600 non-null    object
# dtypes: object(7)
# memory usage: 32.9+ KB

# %%
d_comp = pd.concat([d1[['Dataset', 'Texto', 'Distorsión']], d2[['Dataset', 'Texto', 'Distorsión']], d3[['Dataset', 'Texto', 'Distorsión']]])
d_comp.reset_index(drop=True, inplace=True)
d_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3858 entries, 0 to 3857
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dataset     3858 non-null   object
#  1   Texto       3858 non-null   object
#  2   Distorsión  3858 non-null   object
# dtypes: object(3)
# memory usage: 90.5+ KB

# %%
d_comp.tail()
# Out:
#      Dataset                                              Texto  \
# 3853      D3  last week i went in for a job interview that i...
# 3854      D3  my neighbors downstairs were having a party, a...
# 3855      D3  my neighbors downstairs were having a party, a...
# 3856      D3  one of my friend posted a video of a spider ge...
# 3857      D3  one of my friend posted a video of a spider ge...
#
#                                              Distorsión
# 3853                 Error del adivino,catastroficación
# 3854  Etiquetamiento erróneo,Descalificación de lo p...
# 3855  Etiquetamiento erróneo,Descalificación de lo p...
# 3856                                   Lectura de mente
# 3857                                    Personalización

# %%
def combinar_etiquetas(grupo):
    etiquetas = set()
    for item in grupo:
        etiquetas.update(item.split(','))
    return ','.join(sorted(etiquetas))

df_agrupado = d_comp.groupby('Texto')['Distorsión'].apply(combinar_etiquetas).reset_index()
df_fuentes = d_comp.drop_duplicates(subset=['Texto']).set_index('Texto')['Dataset']
df_final = df_agrupado.join(df_fuentes, on='Texto')
df_final = df_final[['Dataset', 'Texto', 'Distorsión']]
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3552 entries, 0 to 3551
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dataset     3552 non-null   object
#  1   Texto       3552 non-null   object
#  2   Distorsión  3552 non-null   object
# dtypes: object(3)
# memory usage: 83.4+ KB

# %%
df_final.tail()
# Out:
#      Dataset                                              Texto  \
# 3547      D1  …a little crazy and totally lost: I’m 17 and f...
# 3548      D1  …and spanked for punishment. Why do I have thi...
# 3549      D1  …but it seems different to other experiences p...
# 3550      D1  …counting to certain number, punishing myself ...
# 3551      D1  …to hold on to …I am struggling at the moment ...
#
#              Distorsión
# 3547   Lectura de mente
# 3548     Sin distorsión
# 3549  Error del adivino
# 3550  Error del adivino
# 3551    Debería (frase)

# %%
labels = df_final['Distorsión'].str.split(',', expand=True).stack()
frecuencia = labels.value_counts().reset_index()
frecuencia.columns = ['Distorsión', 'Frecuencia']
frecuencia["Frecuencia (%)"] = frecuencia["Frecuencia"]/frecuencia["Frecuencia"].sum()*100
frecuencia
# Out:
#                         Distorsión  Frecuencia  Frecuencia (%)
# 0                   Sin distorsión         950       21.101733
# 1           Etiquetamiento erróneo         510       11.328299
# 2                Error del adivino         432        9.595735
# 3              Sobregeneralización         409        9.084851
# 4                 Lectura de mente         356        7.907597
# 5                    Filtro mental         355        7.885384
# 6                    Magnificación         337        7.485562
# 7                  Personalización         265        5.886273
# 8                      Todo o nada         210        4.664594
# 9           Razonamiento emocional         207        4.597956
# 10                 Debería (frase)         199        4.420258
# 11  Sentimiento o emoción negativa          96        2.132386
# 12                  Culpar a otros          75        1.665926
# 13                catastroficación          49        1.088405
# 14  Descalificación de lo positivo          42        0.932919
# 15    Comparaciones desalentadoras          10        0.222124

# %% [markdown]
# Eliminar los <4%

# %%
etiquetas_baja_frecuencia = frecuencia[frecuencia['Frecuencia (%)'] < 4]['Distorsión']
def filtro_etiquetas(row):
  etiquetas = row['Distorsión'].split(',')
  return not any(etiqueta in etiquetas_baja_frecuencia.values for etiqueta in etiquetas)

df_filtrado = df_final[df_final.apply(filtro_etiquetas, axis=1)]
df_filtrado = df_filtrado.sort_values(by='Dataset')
df_filtrado.reset_index(drop=True, inplace=True)
df_filtrado
# Out:
#      Dataset                                              Texto  \
# 0         D1   (I’ve edited this letter down by half) From a...
# 1         D1  I love my elder sister very much and have not ...
# 2         D1  I love with my dad and his long term girlfrien...
# 3         D1  I make a girl friend some six months ago and w...
# 4         D1  I married 18 years ago with 1 child. 20 years ...
# ...      ...                                                ...
# 3311      D3  I am walking down the street in a new red jean...
# 3312      D3  My girlfriend was distracted by other men at t...
# 3313      D3  My girlfriend was sad that I wanted to go out ...
# 3314      D3  I am unable to give my children any time A goo...
# 3315      D3  I don't know why I am writing the essay Nobody...
#
#                                              Distorsión
# 0                                        Sin distorsión
# 1                                        Sin distorsión
# 2                                       Personalización
# 3                             Magnificación,Todo o nada
# 4                                        Sin distorsión
# ...                                                 ...
# 3311                                    Debería (frase)
# 3312  Lectura de mente,Personalización,Sobregenerali...
# 3313                Personalización,Sobregeneralización
# 3314                                Sobregeneralización
# 3315                                Sobregeneralización
#
# [3316 rows x 3 columns]

# %% [markdown]
# ## Exportar Dataset completo

# %%
df_filtrado.to_excel('Datasets/dataset.xlsx', index=False)
